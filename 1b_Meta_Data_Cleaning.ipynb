# %% [markdown]
# Remaining Tasks:
# 1) Table of contents mapping
# 2) Conclusion
# 3) Objective

# %% [markdown]
# # 1b Meta Data Cleaning

# %% [markdown]
# Author: Jason Truong
#
# Date: Aug 14, 2022
#
# Email: jasontruong19@gmail.com

# %% [markdown]
# This Jupyter workbook contains the meta data for the Movies and TV Amazon reviews. The data was sourced from https://nijianmo.github.io/amazon/index.html.
#
# **Citing source:** Justifying recommendations using distantly-labeled reviews and fined-grained aspects
# Jianmo Ni, Jiacheng Li, Julian McAuley
# Empirical Methods in Natural Language Processing (EMNLP), 2019

# %% [markdown]
# # Table of Contents
#
# 1. [Objective](#1Objective)
# 2. [Data Processing](#2Preliminary)
#     2.1. [Process `Date` column](#2_1Overall)
#     2.2. [Process columns `tech1`, `fit`, `tech2` and `similar item`](#2_2Review)
#     2.3. [Process `price` column](#2_3Vote)
#     2.4. [Process `feature` column](#2_4Drop)
#     2.5. [Process `main_cat` column](#)
#     2.6. [Process `title` column](#)
#     2.7. [Process `description` column](#)
#     2.8. [Process `category` column](#)
#     2.9. [Process `rank` column](#)
#     2.10. [Process `details` column](#)
#     2.11. [Remove the Also_Buy and Also_view columns](#)
# 3. [Export Preprocessed Data](#4Test_Train)
# 4. [Conclusion and Future Work](#3NLP)

# %% [markdown]
# # 1. Objective

# %% [markdown]
# To preprocess the Amazon product review

# %% [markdown]
# # 2. Data Proccessing

# %%
# Import dependencies
import random
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read in the data from the json file

# %%
# If the dataset is too big and only a portion of the data can be loaded in
# meta_data = []
# with open('meta_Movies_and_TV.json','r') as metafile:
#     for x in range(50000):
#         meta_data.append(json.loads(next(metafile)))

# %%
meta_data = []

# Read in every line of the json file
for line in open('meta_Movies_and_TV.json','r'):
    meta_data.append(json.loads(line))

# %%
meta_data[0]
# Out:
# {'category': ['Movies & TV', 'Movies'],
#  'tech1': '',
#  'description': [],
#  'fit': '',
#  'title': 'Understanding Seizures and Epilepsy',
#  'also_buy': [],
#  'tech2': '',
#  'brand': '',
#  'feature': [],
#  'rank': '886,503 in Movies & TV (',
#  'also_view': [],
#  'main_cat': 'Movies & TV',
#  'similar_item': '',
#  'date': '',
#  'price': '',
#  'asin': '0000695009',
#  'imageURL': [],
#  'imageURLHighRes': []}

# %% [markdown]
# Create dataframe

# %%
meta_df = pd.DataFrame(meta_data)

# %% [markdown]
# Check the data types and see if there are any null values in the dataframe

# %%
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203766 entries, 0 to 203765
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   category         203766 non-null  object
#  1   tech1            203766 non-null  object
#  2   description      203766 non-null  object
#  3   fit              203766 non-null  object
#  4   title            203766 non-null  object
#  5   also_buy         203766 non-null  object
#  6   tech2            203766 non-null  object
#  7   brand            203766 non-null  object
#  8   feature          203766 non-null  object
#  9   rank             203766 non-null  object
#  10  also_view        203766 non-null  object
#  11  main_cat         203766 non-null  object
#  12  similar_item     203766 non-null  object
#  13  date             203766 non-null  object
#  14  price            203766 non-null  object
#  15  asin             203766 non-null  object
#  16  imageURL         203766 non-null  object
#  17  imageURLHighRes  203766 non-null  object
#  18  details          195392 non-null  object
# dtypes: object(19)
# memory usage: 29.5+ MB

# %% [markdown]
# At first glance, there seems to be null values in the detail column.

# %%
meta_df.head()
# Out:
#                 category tech1  \
# 0  [Movies & TV, Movies]
# 1  [Movies & TV, Movies]
# 2  [Movies & TV, Movies]
# 3  [Movies & TV, Movies]
# 4  [Movies & TV, Movies]
#
#                                          description fit  \
# 0                                                 []
# 1                                                 []
# 2  [Disc 1: Flour Power (Scones; Shortcakes; Sout...
# 3  [Barefoot Contessa Volume 2: On these three di...
# 4  [Rise and Swine (Good Eats Vol. 7) includes bo...
#
#                                                title  \
# 0                Understanding Seizures and Epilepsy
# 1  Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                  My Fair Pastry (Good Eats Vol. 9)
# 3  Barefoot Contessa (with Ina Garten), Entertain...
# 4                  Rise and Swine (Good Eats Vol. 7)
#
#                                             also_buy tech2        brand  \
# 0                                                 []
# 1                                                 []
# 2                                                 []        Alton Brown
# 3  [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 4                           [B000P1CKES, B000NR4CRM]        Alton Brown
#
#   feature                      rank  \
# 0      []  886,503 in Movies & TV (
# 1      []  342,688 in Movies & TV (
# 2      []  370,026 in Movies & TV (
# 3      []  342,914 in Movies & TV (
# 4      []  351,684 in Movies & TV (
#
#                                            also_view     main_cat  \
# 0                                                 []  Movies & TV
# 1                                                 []  Movies & TV
# 2                                                 []  Movies & TV
# 3  [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  Movies & TV
# 4                                       [B0015SVNXY]  Movies & TV
#
#   similar_item date   price        asin  \
# 0                            0000695009
# 1                            0000791156
# 2                            0000143529
# 3                    $74.95  0000143588
# 4                            0000143502
#
#                                             imageURL  \
# 0                                                 []
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3                                                 []
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                                      imageURLHighRes details
# 0                                                 []     NaN
# 1  [https://images-na.ssl-images-amazon.com/image...     NaN
# 2  [https://images-na.ssl-images-amazon.com/image...     NaN
# 3                                                 []     NaN
# 4  [https://images-na.ssl-images-amazon.com/image...     NaN

# %% [markdown]
# **Image data is not being considered in this NLP recommendation project so `imageURL` and `imageURLHighRes` will be dropped**

# %%
# Drop columns:
meta_df.drop(columns = ['imageURL','imageURLHighRes'], inplace = True)

# %%
# Check dataframe:
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203766 entries, 0 to 203765
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   category      203766 non-null  object
#  1   tech1         203766 non-null  object
#  2   description   203766 non-null  object
#  3   fit           203766 non-null  object
#  4   title         203766 non-null  object
#  5   also_buy      203766 non-null  object
#  6   tech2         203766 non-null  object
#  7   brand         203766 non-null  object
#  8   feature       203766 non-null  object
#  9   rank          203766 non-null  object
#  10  also_view     203766 non-null  object
#  11  main_cat      203766 non-null  object
#  12  similar_item  203766 non-null  object
#  13  date          203766 non-null  object
#  14  price         203766 non-null  object
#  15  asin          203766 non-null  object
#  16  details       195392 non-null  object
# dtypes: object(17)
# memory usage: 26.4+ MB

# %% [markdown]
# Columns `tech`,`fit`,`tech2`,`similar item`, `date`, `price`, `feature`,`rank` and `details` may have null values

# %% [markdown]
# ## Process `Date` column

# %%
blank_dates = sum(meta_df['date'] == "")

# %%
# Determine the proportion of blank dates
(blank_dates/meta_df.shape[0])*100
# Out:
# 99.9813511577005

# %% [markdown]
# 99.98% of the `date` column is blank so the column will be dropped

# %%
meta_df.drop(columns = 'date', inplace = True)

# %% [markdown]
# Check that the column has been dropped

# %%
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203766 entries, 0 to 203765
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   category      203766 non-null  object
#  1   tech1         203766 non-null  object
#  2   description   203766 non-null  object
#  3   fit           203766 non-null  object
#  4   title         203766 non-null  object
#  5   also_buy      203766 non-null  object
#  6   tech2         203766 non-null  object
#  7   brand         203766 non-null  object
#  8   feature       203766 non-null  object
#  9   rank          203766 non-null  object
#  10  also_view     203766 non-null  object
#  11  main_cat      203766 non-null  object
#  12  similar_item  203766 non-null  object
#  13  price         203766 non-null  object
#  14  asin          203766 non-null  object
#  15  details       195392 non-null  object
# dtypes: object(16)
# memory usage: 24.9+ MB

# %% [markdown]
# ## Process columns `tech1`, `fit`, `tech2` and `similar item`

# %%
print('# of empty cells in tech1 column:')
print(sum(meta_df['tech1'] == ""))
# Out:
# # of empty cells in tech1 column:
# 203760

# %% [markdown]
# Only 6 out of 203766 entries in the tech1 column have data so this column can be dropped.

# %%
print('# of empty cells in fit column:')
print(sum(meta_df['fit'] == ""))
# Out:
# # of empty cells in fit column:
# 203766

# %%
print('# of empty cells in tech2 column:')
print(sum(meta_df['tech2'] == ""))
# Out:
# # of empty cells in tech2 column:
# 203766

# %%
print('# of empty cells in similar_item column:')
print(sum(meta_df['similar_item'] == ""))
# Out:
# # of empty cells in similar_item column:
# 203766

# %% [markdown]
# Over 99% of the data in the above columns have no data so these columns can be dropped.

# %%
# Drop columns:
meta_df.drop(columns = ['tech1','fit','tech2','similar_item'], inplace = True)

# %%
# Check dataframe:
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203766 entries, 0 to 203765
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   category     203766 non-null  object
#  1   description  203766 non-null  object
#  2   title        203766 non-null  object
#  3   also_buy     203766 non-null  object
#  4   brand        203766 non-null  object
#  5   feature      203766 non-null  object
#  6   rank         203766 non-null  object
#  7   also_view    203766 non-null  object
#  8   main_cat     203766 non-null  object
#  9   price        203766 non-null  object
#  10  asin         203766 non-null  object
#  11  details      195392 non-null  object
# dtypes: object(12)
# memory usage: 18.7+ MB

# %% [markdown]
# ## Process `price` column

# %%
sum(meta_df['price'] == "")/meta_df['price'].shape[0]
# Out:
# 0.45650893672153353

# %% [markdown]
# 45.6% of the price column contains blanks so over 50% contain data, thus this column should not be dropped.

# %%
meta_df[meta_df['price'] != ""]
# Out:
#                                                  category  \
# 3                                   [Movies & TV, Movies]
# 7                                   [Movies & TV, Movies]
# 14                [Movies & TV, Christian Video, General]
# 15      [Movies & TV, Genre for Featured Categories, F...
# 16                                  [Movies & TV, Movies]
# ...                                                   ...
# 203758                              [Movies & TV, Movies]
# 203759                 [Movies & TV, HBO, All HBO Titles]
# 203761  [Movies & TV, Studio Specials, Sony Pictures H...
# 203762                              [Movies & TV, Movies]
# 203763    [Movies & TV, Independently Distributed, Drama]
#
#                                               description  \
# 3       [Barefoot Contessa Volume 2: On these three di...
# 7       [Giada de Laurentis on "Everyday Italian" DVDs...
# 14         [An early movie edition of the life of Jesus.]
# 15                                                     []
# 16                                                  [VHS]
# ...                                                   ...
# 203758  [Between the years of 1954 and 1963, the Rebbe...
# 203759  [<![CDATA[, All the Way (Digital HD/DVD), Brya...
# 203761  [Tony Award-winning director Bartlett Sher pro...
# 203762  [Mr. Miracle DVD Region 2 need an all region D...
# 203763  [The President and his family rule the land wi...
#
#                                                     title  \
# 3       Barefoot Contessa (with Ina Garten), Entertain...
# 7       Everyday Italian (with Giada de Laurentiis), V...
# 14                                 Where Jesus Walked VHS
# 15                          Passion According to Luke VHS
# 16                       The Homecoming Kids Camp Out VHS
# ...                                                   ...
# 203758                                The Rebbe's Nigunim
# 203759                       All the Way (Digital HD/DVD)
# 203761                                      Verdi: Otello
# 203762               Mr. Miracle - Ihn schickt der Himmel
# 203763                                      The President
#
#                                                  also_buy              brand  \
# 3       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 7                                [B002I5GNVU, B000KL8ODE]
# 14                                                     []
# 15                                                     []
# 16                                                     []
# ...                                                   ...                ...
# 203758  [B00V3UOVBA, B07J22VS9C, B06WGSL4J6, B00HSC0OJ...     Benny Friedman
# 203759  [B077SKJCWZ, B001BSBC16, B00CLH08KC, B076ZR2F9...            Various
# 203761  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 203762                                                 []
# 203763  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
#
#        feature                        rank  \
# 3           []    342,914 in Movies & TV (
# 7           []    409,173 in Movies & TV (
# 14          []  1,108,385 in Movies & TV (
# 15          []    692,122 in Movies & TV (
# 16          []    390,381 in Movies & TV (
# ...        ...                         ...
# 203758      []    120,487 in Movies & TV (
# 203759      []     50,367 in Movies & TV (
# 203761      []     68,026 in Movies & TV (
# 203762      []    344,483 in Movies & TV (
# 203763      []    199,854 in Movies & TV (
#
#                                                 also_view     main_cat  \
# 3       [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  Movies & TV
# 7                                            [B000KL8ODE]  Movies & TV
# 14                                                     []  Movies & TV
# 15                                                     []  Movies & TV
# 16                                                     []  Movies & TV
# ...                                                   ...          ...
# 203758                                       [B07J22VS9C]  Movies & TV
# 203759  [B077SKJCWZ, B001BSBC16, B00CLH08KC, B078952HS...  Movies & TV
# 203761  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...  Movies & TV
# 203762                                                 []  Movies & TV
# 203763                           [B01GWCHP2U, B0009PW3RE]  Movies & TV
#
#                                                     price        asin  \
# 3                                                  $74.95  0000143588
# 7                                                  $24.95  0000143561
# 14      .a-box-inner{background-color:#fff}#alohaBuyBo...  0005000009
# 15      .a-box-inner{background-color:#fff}#alohaBuyBo...  0005054885
# 16      .a-box-inner{background-color:#fff}#alohaBuyBo...  0005059836
# ...                                                   ...         ...
# 203758                                             $21.99  B01HIQHDAS
# 203759                                              $7.90  B01HIUL6WU
# 203761                                             $14.98  B01HJ1INB0
# 203762                                             $16.18  B01HJ3E0PQ
# 203763                                             $18.99  B01HJ6R77G
#
#                                                   details
# 3                                                     NaN
# 7                                                     NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 203758                           {'ASIN: ': 'B01HIQHDAS'}
# 203759  {'Language:': 'English', 'Dubbed:': 'English',...
# 203761  {'Language:': 'English', 'Subtitles:': 'Italia...
# 203762  {'Language:': 'German (Dolby Digital 5.1), Eng...
# 203763  {'Language:': 'Georgian', 'Subtitles:': 'Engli...
#
# [110745 rows x 12 columns]

# %% [markdown]
# After reviewing the goal of the project. Specifically for the recommendation system, the price of the item will not be taken into consideration as half the price values are missing. For future work, these prices will determined from web scraping the Amazon site for more accurate pricing. Thus this column will be dropped.

# %%
meta_df.drop(columns='price', inplace=True)

# Check results
meta_df.head()
# Out:
#                 category                                        description  \
# 0  [Movies & TV, Movies]                                                 []
# 1  [Movies & TV, Movies]                                                 []
# 2  [Movies & TV, Movies]  [Disc 1: Flour Power (Scones; Shortcakes; Sout...
# 3  [Movies & TV, Movies]  [Barefoot Contessa Volume 2: On these three di...
# 4  [Movies & TV, Movies]  [Rise and Swine (Good Eats Vol. 7) includes bo...
#
#                                                title  \
# 0                Understanding Seizures and Epilepsy
# 1  Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                  My Fair Pastry (Good Eats Vol. 9)
# 3  Barefoot Contessa (with Ina Garten), Entertain...
# 4                  Rise and Swine (Good Eats Vol. 7)
#
#                                             also_buy        brand feature  \
# 0                                                 []                   []
# 1                                                 []                   []
# 2                                                 []  Alton Brown      []
# 3  [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...   Ina Garten      []
# 4                           [B000P1CKES, B000NR4CRM]  Alton Brown      []
#
#                        rank  \
# 0  886,503 in Movies & TV (
# 1  342,688 in Movies & TV (
# 2  370,026 in Movies & TV (
# 3  342,914 in Movies & TV (
# 4  351,684 in Movies & TV (
#
#                                            also_view     main_cat        asin  \
# 0                                                 []  Movies & TV  0000695009
# 1                                                 []  Movies & TV  0000791156
# 2                                                 []  Movies & TV  0000143529
# 3  [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  Movies & TV  0000143588
# 4                                       [B0015SVNXY]  Movies & TV  0000143502
#
#   details
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# ## Process `feature` column

# %%
meta_df['feature'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  203594
# [Officially Licensed, Highest Quality Recording]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        34
# [Shrink-wrapped]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         5
# [Factory sealed DVD]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     4
# [Step-by-step program to teach you the fundamentals of Little League Baseball. Coached by All-Star Rex "Wonder Dog" Hudler., Learn the basics: choosing, breaking in and caring for your glove + Proper body position for fielding grounders & pop ups + Good footwork +, Throwing to the bases + Playing the positions + Practice drills + Tips from Major League pros!, Run time: about 45 minutes, Hosted by Ray Romano from "Everybody Loves Raymond"]                                                                                                                                                                                                                                                                                                                                                                                                                               2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# [runtime: 41 minutes, format: 16:9 anamorphic]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# [Based on the bestselling Christmas tradition The Elf on the Shelf, Includes code for Santa's Secret website, Includes 3-D version of the Christmas special]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# [Pint-sized troublemaker Dennis The Menace hits the high seas in this made-for-TV animated feature. Mr. Wilson (voice of Tom Arnold) and his wife Martha (voice of Marilyn Lightstone) decide to take an ocean cruise to get away from it all, but much to Mr. Wilson&#39;s chagrin, he discovers one thorn in his side will be following him -- Henry and Alice Mitchell (voices of Maurice LaMarche and Marilyn]                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [Standard screen, Printable materials for educators, Access to the NOVA web site, Scene selection, Closed captions]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [Volume 2, 10 Zumba tracks from the Incredible Results DVD collection, Total Length: 40:01, Includes a mix of Salsa, Electro Dance, Rumba Flamenca, Reggaeton, Champeta and more, Zumba Music CD, <span>\n        Buy More, Save More! Buy 2 Zumba Products from Global Z Fitness, Get 10% off, 3 items, 25% off, or 4 items, 30% off!\n        \n        \n        <span class="a-declarative" data-action="a-modal" data-a-modal="{&quot;width&quot;:&quot;450&quot;,&quot;header&quot;:&quot;Promotion Details&quot;,&quot;url&quot;:&quot;/gp/promotions/details/popup/A2FPNUTUIHINQK&quot;,&quot;height&quot;:&quot;600&quot;}">\n            <a href="javascript:void(0)" class="a-popover-trigger a-declarative">  \n            Here's how\n            <i class="a-icon a-icon-popover"></i></a>\n        </span>\n        (restrictions apply)\n        \n    </span>]         1
# Name: feature, Length: 127, dtype: int64

# %%
blank_features = meta_df['feature'].value_counts()[0]

# %%
# Determine the number of blank features
(blank_features/meta_df.shape[0])*100
# Out:
# 99.91558945064438

# %% [markdown]
# 99.9% of this column are blanks so this column should be dropped.

# %%
# Drop columns:
meta_df.drop(columns = ['feature'], inplace = True)

# %%
# Check dataframe:
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203766 entries, 0 to 203765
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   category     203766 non-null  object
#  1   description  203766 non-null  object
#  2   title        203766 non-null  object
#  3   also_buy     203766 non-null  object
#  4   brand        203766 non-null  object
#  5   rank         203766 non-null  object
#  6   also_view    203766 non-null  object
#  7   main_cat     203766 non-null  object
#  8   asin         203766 non-null  object
#  9   details      195392 non-null  object
# dtypes: object(10)
# memory usage: 15.5+ MB

# %% [markdown]
# ## Process `main_cat` column

# %% [markdown]
# The value counts method will be used to determine the data in the main category column.

# %%
meta_df['main_cat'].value_counts()
# Out:
# Movies & TV                                                                                                                                                                  203464
# Sports & Outdoors                                                                                                                                                               118
# Books                                                                                                                                                                            35
# Amazon Home                                                                                                                                                                      33
# <img src="https://images-na.ssl-images-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>        31
# Toys & Games                                                                                                                                                                     17
# All Electronics                                                                                                                                                                  10
#                                                                                                                                                                                  10
# Cell Phones & Accessories                                                                                                                                                         9
# Industrial & Scientific                                                                                                                                                           8
# Health & Personal Care                                                                                                                                                            7
# <img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>          6
# Arts, Crafts & Sewing                                                                                                                                                             3
# All Beauty                                                                                                                                                                        3
# Tools & Home Improvement                                                                                                                                                          2
# Pet Supplies                                                                                                                                                                      2
# Office Products                                                                                                                                                                   2
# Musical Instruments                                                                                                                                                               1
# Video Games                                                                                                                                                                       1
# Grocery                                                                                                                                                                           1
# Camera & Photo                                                                                                                                                                    1
# Baby                                                                                                                                                                              1
# Home Audio & Theater                                                                                                                                                              1
# Name: main_cat, dtype: int64

# %%
203464/203766
# Out:
# 0.9985179077961976

# %% [markdown]
# Since the Movies & TV category represents the majority of the data, the other categories will be dropped to focus on Movies & TV

# %%
# Find the rows where the the main category is Movies & TV and store it in the meta_df. 
meta_df = meta_df[meta_df['main_cat'] == 'Movies & TV'].reset_index(drop=True)

# Check results
meta_df
# Out:
#                                                  category  \
# 0                                   [Movies & TV, Movies]
# 1                                   [Movies & TV, Movies]
# 2                                   [Movies & TV, Movies]
# 3                                   [Movies & TV, Movies]
# 4                                   [Movies & TV, Movies]
# ...                                                   ...
# 203459  [Movies & TV, Studio Specials, Sony Pictures H...
# 203460                              [Movies & TV, Movies]
# 203461    [Movies & TV, Independently Distributed, Drama]
# 203462  [Movies & TV, Genre for Featured Categories, A...
# 203463                     [Movies & TV, Blu-ray, Movies]
#
#                                               description  \
# 0                                                      []
# 1                                                      []
# 2       [Disc 1: Flour Power (Scones; Shortcakes; Sout...
# 3       [Barefoot Contessa Volume 2: On these three di...
# 4       [Rise and Swine (Good Eats Vol. 7) includes bo...
# ...                                                   ...
# 203459  [Tony Award-winning director Bartlett Sher pro...
# 203460  [Mr. Miracle DVD Region 2 need an all region D...
# 203461  [The President and his family rule the land wi...
# 203462  [Filmed in 1972 as Pope Joan, Michael Anderson...
# 203463                              [Japanese Rare Items]
#
#                                                     title  \
# 0                     Understanding Seizures and Epilepsy
# 1       Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                       My Fair Pastry (Good Eats Vol. 9)
# 3       Barefoot Contessa (with Ina Garten), Entertain...
# 4                       Rise and Swine (Good Eats Vol. 7)
# ...                                                   ...
# 203459                                      Verdi: Otello
# 203460               Mr. Miracle - Ihn schickt der Himmel
# 203461                                      The President
# 203462                          She.....Who Would Be Pope
# 203463  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []
# 1                                                      []
# 2                                                      []        Alton Brown
# 3       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 4                                [B000P1CKES, B000NR4CRM]        Alton Brown
# ...                                                   ...                ...
# 203459  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 203460                                                 []
# 203461  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 203462                                       [B004L690XW]        Liv Ullmann
# 203463  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#                             rank  \
# 0       886,503 in Movies & TV (
# 1       342,688 in Movies & TV (
# 2       370,026 in Movies & TV (
# 3       342,914 in Movies & TV (
# 4       351,684 in Movies & TV (
# ...                          ...
# 203459   68,026 in Movies & TV (
# 203460  344,483 in Movies & TV (
# 203461  199,854 in Movies & TV (
# 203462  246,494 in Movies & TV (
# 203463  239,915 in Movies & TV (
#
#                                                 also_view     main_cat  \
# 0                                                      []  Movies & TV
# 1                                                      []  Movies & TV
# 2                                                      []  Movies & TV
# 3       [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  Movies & TV
# 4                                            [B0015SVNXY]  Movies & TV
# ...                                                   ...          ...
# 203459  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...  Movies & TV
# 203460                                                 []  Movies & TV
# 203461                           [B01GWCHP2U, B0009PW3RE]  Movies & TV
# 203462                                       [B0000C23HX]  Movies & TV
# 203463  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...  Movies & TV
#
#               asin                                            details
# 0       0000695009                                                NaN
# 1       0000791156                                                NaN
# 2       0000143529                                                NaN
# 3       0000143588                                                NaN
# 4       0000143502                                                NaN
# ...            ...                                                ...
# 203459  B01HJ1INB0  {'Language:': 'English', 'Subtitles:': 'Italia...
# 203460  B01HJ3E0PQ  {'Language:': 'German (Dolby Digital 5.1), Eng...
# 203461  B01HJ6R77G  {'Language:': 'Georgian', 'Subtitles:': 'Engli...
# 203462  B01HJCCLOY   {'Language:': 'English', 'ASIN: ': 'B01HJCCLOY'}
# 203463  B01HJF79XO                           {'ASIN: ': 'B01HJF79XO'}
#
# [203464 rows x 10 columns]

# %%
meta_df['main_cat'].value_counts()
# Out:
# Movies & TV    203464
# Name: main_cat, dtype: int64

# %% [markdown]
# Since the data only contains Movies & TV, the main_cat column can be dropped because it isn't providing any useful information.

# %%
# Drop columns:
meta_df.drop(columns = 'main_cat', inplace = True)

# %%
# Check dataframe:
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203464 entries, 0 to 203463
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   category     203464 non-null  object
#  1   description  203464 non-null  object
#  2   title        203464 non-null  object
#  3   also_buy     203464 non-null  object
#  4   brand        203464 non-null  object
#  5   rank         203464 non-null  object
#  6   also_view    203464 non-null  object
#  7   asin         203464 non-null  object
#  8   details      195104 non-null  object
# dtypes: object(9)
# memory usage: 14.0+ MB

# %% [markdown]
# ## Process `title` column

# %%
meta_df['title'].value_counts()
# Out:
#                                                                                                                      59
# Treasure Island                                                                                                      15
# Live                                                                                                                 11
# Carmen                                                                                                               10
#  WWE                                                                                                                 10
#                                                                                                                      ..
# Embracing the Tiger                                                                                                   1
# DVD BUNDLE: Qigong for Beginners Bundle - Beginner Qigong Exercise 2-DVD / 2-book set (Dr. Yang, Jwing-Ming) YMAA     1
# The Itsy Bitsy Tiger And Other Ridiculous Stories and Songs                                                           1
# Le Roi Et Moi                                                                                                         1
# Castle Of The Living Dead                                                                                             1
# Name: title, Length: 177707, dtype: int64

# %%
sum(meta_df['title'] =='')/meta_df['title'].shape[0]
# Out:
# 0.0002899775881728463

# %% [markdown]
# The title column contains the title of the movie and only 0.03% of the column contains a null value so this column must be kept.

# %% [markdown]
# ## Process `description` column

# %% [markdown]
# The description column is in a list so it will be converted to a list to check the contents within the list.

# %%
desc_split_df = pd.DataFrame(meta_df['description'].tolist()).add_prefix('description_')
desc_split_df
# Out:
#                                             description_0  \
# 0                                                    None
# 1                                                    None
# 2       Disc 1: Flour Power (Scones; Shortcakes; South...
# 3       Barefoot Contessa Volume 2: On these three dis...
# 4       Rise and Swine (Good Eats Vol. 7) includes bon...
# ...                                                   ...
# 203459  Tony Award-winning director Bartlett Sher prob...
# 203460  Mr. Miracle DVD Region 2 need an all region DV...
# 203461  The President and his family rule the land wit...
# 203462  Filmed in 1972 as Pope Joan, Michael Andersons...
# 203463                                Japanese Rare Items
#
#                                             description_1 description_2  \
# 0                                                    None          None
# 1                                                    None          None
# 2                                                    None          None
# 3                                                    None          None
# 4                                                    None          None
# ...                                                   ...           ...
# 203459                                               None          None
# 203460                                               None          None
# 203461  WINNER - Best Film - Chicago Int'l Film Festiv...          None
# 203462                                               None          None
# 203463                                               None          None
#
#        description_3 description_4 description_5 description_6 description_7  \
# 0               None          None          None          None          None
# 1               None          None          None          None          None
# 2               None          None          None          None          None
# 3               None          None          None          None          None
# 4               None          None          None          None          None
# ...              ...           ...           ...           ...           ...
# 203459          None          None          None          None          None
# 203460          None          None          None          None          None
# 203461          None          None          None          None          None
# 203462          None          None          None          None          None
# 203463          None          None          None          None          None
#
#        description_8 description_9  ... description_597 description_598  \
# 0               None          None  ...            None            None
# 1               None          None  ...            None            None
# 2               None          None  ...            None            None
# 3               None          None  ...            None            None
# 4               None          None  ...            None            None
# ...              ...           ...  ...             ...             ...
# 203459          None          None  ...            None            None
# 203460          None          None  ...            None            None
# 203461          None          None  ...            None            None
# 203462          None          None  ...            None            None
# 203463          None          None  ...            None            None
#
#        description_599 description_600 description_601 description_602  \
# 0                 None            None            None            None
# 1                 None            None            None            None
# 2                 None            None            None            None
# 3                 None            None            None            None
# 4                 None            None            None            None
# ...                ...             ...             ...             ...
# 203459            None            None            None            None
# 203460            None            None            None            None
# 203461            None            None            None            None
# 203462            None            None            None            None
# 203463            None            None            None            None
#
#        description_603 description_604 description_605 description_606
# 0                 None            None            None            None
# 1                 None            None            None            None
# 2                 None            None            None            None
# 3                 None            None            None            None
# 4                 None            None            None            None
# ...                ...             ...             ...             ...
# 203459            None            None            None            None
# 203460            None            None            None            None
# 203461            None            None            None            None
# 203462            None            None            None            None
# 203463            None            None            None            None
#
# [203464 rows x 607 columns]

# %%
(desc_split_df.isna().sum())/desc_split_df.shape[0]
# Out:
# description_0      0.142295
# description_1      0.790346
# description_2      0.944147
# description_3      0.970437
# description_4      0.980011
#                      ...
# description_602    0.999995
# description_603    0.999995
# description_604    0.999995
# description_605    0.999995
# description_606    0.999995
# Length: 607, dtype: float64

# %% [markdown]
# Keep the first 1 columns since atleast 79% are null for all the other columns and the first column represents the main description which is the most important portion.

# %%
meta_df['description_0'] = desc_split_df['description_0']
meta_df
# Out:
#                                                  category  \
# 0                                   [Movies & TV, Movies]
# 1                                   [Movies & TV, Movies]
# 2                                   [Movies & TV, Movies]
# 3                                   [Movies & TV, Movies]
# 4                                   [Movies & TV, Movies]
# ...                                                   ...
# 203459  [Movies & TV, Studio Specials, Sony Pictures H...
# 203460                              [Movies & TV, Movies]
# 203461    [Movies & TV, Independently Distributed, Drama]
# 203462  [Movies & TV, Genre for Featured Categories, A...
# 203463                     [Movies & TV, Blu-ray, Movies]
#
#                                               description  \
# 0                                                      []
# 1                                                      []
# 2       [Disc 1: Flour Power (Scones; Shortcakes; Sout...
# 3       [Barefoot Contessa Volume 2: On these three di...
# 4       [Rise and Swine (Good Eats Vol. 7) includes bo...
# ...                                                   ...
# 203459  [Tony Award-winning director Bartlett Sher pro...
# 203460  [Mr. Miracle DVD Region 2 need an all region D...
# 203461  [The President and his family rule the land wi...
# 203462  [Filmed in 1972 as Pope Joan, Michael Anderson...
# 203463                              [Japanese Rare Items]
#
#                                                     title  \
# 0                     Understanding Seizures and Epilepsy
# 1       Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                       My Fair Pastry (Good Eats Vol. 9)
# 3       Barefoot Contessa (with Ina Garten), Entertain...
# 4                       Rise and Swine (Good Eats Vol. 7)
# ...                                                   ...
# 203459                                      Verdi: Otello
# 203460               Mr. Miracle - Ihn schickt der Himmel
# 203461                                      The President
# 203462                          She.....Who Would Be Pope
# 203463  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []
# 1                                                      []
# 2                                                      []        Alton Brown
# 3       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 4                                [B000P1CKES, B000NR4CRM]        Alton Brown
# ...                                                   ...                ...
# 203459  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 203460                                                 []
# 203461  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 203462                                       [B004L690XW]        Liv Ullmann
# 203463  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#                             rank  \
# 0       886,503 in Movies & TV (
# 1       342,688 in Movies & TV (
# 2       370,026 in Movies & TV (
# 3       342,914 in Movies & TV (
# 4       351,684 in Movies & TV (
# ...                          ...
# 203459   68,026 in Movies & TV (
# 203460  344,483 in Movies & TV (
# 203461  199,854 in Movies & TV (
# 203462  246,494 in Movies & TV (
# 203463  239,915 in Movies & TV (
#
#                                                 also_view        asin  \
# 0                                                      []  0000695009
# 1                                                      []  0000791156
# 2                                                      []  0000143529
# 3       [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  0000143588
# 4                                            [B0015SVNXY]  0000143502
# ...                                                   ...         ...
# 203459  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...  B01HJ1INB0
# 203460                                                 []  B01HJ3E0PQ
# 203461                           [B01GWCHP2U, B0009PW3RE]  B01HJ6R77G
# 203462                                       [B0000C23HX]  B01HJCCLOY
# 203463  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...  B01HJF79XO
#
#                                                   details  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 203459  {'Language:': 'English', 'Subtitles:': 'Italia...
# 203460  {'Language:': 'German (Dolby Digital 5.1), Eng...
# 203461  {'Language:': 'Georgian', 'Subtitles:': 'Engli...
# 203462   {'Language:': 'English', 'ASIN: ': 'B01HJCCLOY'}
# 203463                           {'ASIN: ': 'B01HJF79XO'}
#
#                                             description_0
# 0                                                    None
# 1                                                    None
# 2       Disc 1: Flour Power (Scones; Shortcakes; South...
# 3       Barefoot Contessa Volume 2: On these three dis...
# 4       Rise and Swine (Good Eats Vol. 7) includes bon...
# ...                                                   ...
# 203459  Tony Award-winning director Bartlett Sher prob...
# 203460  Mr. Miracle DVD Region 2 need an all region DV...
# 203461  The President and his family rule the land wit...
# 203462  Filmed in 1972 as Pope Joan, Michael Andersons...
# 203463                                Japanese Rare Items
#
# [203464 rows x 10 columns]

# %% [markdown]
# Drop the original description column

# %%
meta_df.drop(columns = 'description', inplace = True)
meta_df
# Out:
#                                                  category  \
# 0                                   [Movies & TV, Movies]
# 1                                   [Movies & TV, Movies]
# 2                                   [Movies & TV, Movies]
# 3                                   [Movies & TV, Movies]
# 4                                   [Movies & TV, Movies]
# ...                                                   ...
# 203459  [Movies & TV, Studio Specials, Sony Pictures H...
# 203460                              [Movies & TV, Movies]
# 203461    [Movies & TV, Independently Distributed, Drama]
# 203462  [Movies & TV, Genre for Featured Categories, A...
# 203463                     [Movies & TV, Blu-ray, Movies]
#
#                                                     title  \
# 0                     Understanding Seizures and Epilepsy
# 1       Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                       My Fair Pastry (Good Eats Vol. 9)
# 3       Barefoot Contessa (with Ina Garten), Entertain...
# 4                       Rise and Swine (Good Eats Vol. 7)
# ...                                                   ...
# 203459                                      Verdi: Otello
# 203460               Mr. Miracle - Ihn schickt der Himmel
# 203461                                      The President
# 203462                          She.....Who Would Be Pope
# 203463  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []
# 1                                                      []
# 2                                                      []        Alton Brown
# 3       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 4                                [B000P1CKES, B000NR4CRM]        Alton Brown
# ...                                                   ...                ...
# 203459  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 203460                                                 []
# 203461  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 203462                                       [B004L690XW]        Liv Ullmann
# 203463  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#                             rank  \
# 0       886,503 in Movies & TV (
# 1       342,688 in Movies & TV (
# 2       370,026 in Movies & TV (
# 3       342,914 in Movies & TV (
# 4       351,684 in Movies & TV (
# ...                          ...
# 203459   68,026 in Movies & TV (
# 203460  344,483 in Movies & TV (
# 203461  199,854 in Movies & TV (
# 203462  246,494 in Movies & TV (
# 203463  239,915 in Movies & TV (
#
#                                                 also_view        asin  \
# 0                                                      []  0000695009
# 1                                                      []  0000791156
# 2                                                      []  0000143529
# 3       [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  0000143588
# 4                                            [B0015SVNXY]  0000143502
# ...                                                   ...         ...
# 203459  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...  B01HJ1INB0
# 203460                                                 []  B01HJ3E0PQ
# 203461                           [B01GWCHP2U, B0009PW3RE]  B01HJ6R77G
# 203462                                       [B0000C23HX]  B01HJCCLOY
# 203463  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...  B01HJF79XO
#
#                                                   details  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 203459  {'Language:': 'English', 'Subtitles:': 'Italia...
# 203460  {'Language:': 'German (Dolby Digital 5.1), Eng...
# 203461  {'Language:': 'Georgian', 'Subtitles:': 'Engli...
# 203462   {'Language:': 'English', 'ASIN: ': 'B01HJCCLOY'}
# 203463                           {'ASIN: ': 'B01HJF79XO'}
#
#                                             description_0
# 0                                                    None
# 1                                                    None
# 2       Disc 1: Flour Power (Scones; Shortcakes; South...
# 3       Barefoot Contessa Volume 2: On these three dis...
# 4       Rise and Swine (Good Eats Vol. 7) includes bon...
# ...                                                   ...
# 203459  Tony Award-winning director Bartlett Sher prob...
# 203460  Mr. Miracle DVD Region 2 need an all region DV...
# 203461  The President and his family rule the land wit...
# 203462  Filmed in 1972 as Pope Joan, Michael Andersons...
# 203463                                Japanese Rare Items
#
# [203464 rows x 9 columns]

# %% [markdown]
# Check rows where the description is empty because the recommendation system will be partially based off of the description column.

# %%
# Find where there are no descriptions
meta_df['description_0'].isna()
# Out:
# 0          True
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 203459    False
# 203460    False
# 203461    False
# 203462    False
# 203463    False
# Name: description_0, Length: 203464, dtype: bool

# %%
meta_df[meta_df['description_0'].isna()]
# Out:
#                                                  category  \
# 0                                   [Movies & TV, Movies]
# 1                                   [Movies & TV, Movies]
# 13      [Movies & TV, Art House & International, By Or...
# 15      [Movies & TV, Genre for Featured Categories, F...
# 18                                  [Movies & TV, Movies]
# ...                                                   ...
# 203426                              [Movies & TV, Movies]
# 203431                              [Movies & TV, Movies]
# 203439                              [Movies & TV, Movies]
# 203442                                  [Movies & TV, TV]
# 203452                     [Movies & TV, Blu-ray, Movies]
#
#                                                     title  \
# 0                     Understanding Seizures and Epilepsy
# 1       Spirit Led&mdash;Moving By Grace In The Holy S...
# 13                                        Peace Child VHS
# 15                          Passion According to Luke VHS
# 18      Dance for Joy - Worship and Praise Through Dav...
# ...                                                   ...
# 203426                                         The Rezort
# 203431  The Raw Chef Academy Raw Decadent Desserts Rus...
# 203439  Trading Spaces 4 Pack (The Best of Trading Spa...
# 203442  Castle : Complete Collection, DVD (Series Seas...
# 203452                         We Still Steal the Old Way
#
#                                                  also_buy          brand  \
# 0                                                      []
# 1                                                      []
# 13                                                     []
# 15                                                     []
# 18                                                     []
# ...                                                   ...            ...
# 203426  [B07HSK1LX4, B06XC76G5K, B0192PERT8, B01N56KV0...
# 203431                                                 []  Russell James
# 203439                                                 []
# 203442  [B07GJLNJR7, B01N95Z9L8, B00UCJ6TPE, B07D51563...
# 203452                                                 []
#
#                             rank  \
# 0       886,503 in Movies & TV (
# 1       342,688 in Movies & TV (
# 13      866,012 in Movies & TV (
# 15      692,122 in Movies & TV (
# 18      710,984 in Movies & TV (
# ...                          ...
# 203426  170,836 in Movies & TV (
# 203431  538,198 in Movies & TV (
# 203439  301,993 in Movies & TV (
# 203442  178,932 in Movies & TV (
# 203452  389,929 in Movies & TV (
#
#                                                 also_view        asin  \
# 0                                                      []  0000695009
# 1                                                      []  0000791156
# 13                                                     []  0001527665
# 15                                                     []  0005054885
# 18                                                     []  0005022134
# ...                                                   ...         ...
# 203426                           [B07624VF27, B01GGJZNX2]  B01HGRJUGE
# 203431                                                 []  B01HH17FAM
# 203439                                                 []  B01HH5I2RI
# 203442  [B07FB3P2WC, B06XRQ935Z, B003L77FYS, B01E7XTFN...  B01HH95M2M
# 203452                                       [B00MODCISI]  B01HI87P4K
#
#                                                   details description_0
# 0                                                     NaN          None
# 1                                                     NaN          None
# 13                                                    NaN          None
# 15                                                    NaN          None
# 18                                                    NaN          None
# ...                                                   ...           ...
# 203426  {'Language:': 'German (Dolby Digital 5.1), Eng...          None
# 203431                           {'ASIN: ': 'B01HH17FAM'}          None
# 203439                           {'ASIN: ': 'B01HH5I2RI'}          None
# 203442                           {'ASIN: ': 'B01HH95M2M'}          None
# 203452   {'Language:': 'English', 'ASIN: ': 'B01HI87P4K'}          None
#
# [28952 rows x 9 columns]

# %% [markdown]
# From a quick scan of the above, it looks like some rows that do not have descriptions have information in the `also_buy` and `also_view` columns. These columns contain important information about the movies but due to time contraints, they will be incorporated into the recommondation system in future works. For simplicity, only the columns that have a description will be kept.

# %%
meta_df = meta_df[meta_df['description_0'].notna()]

# Check results

na_remain = meta_df['description_0'].isna().sum()

print(f'There are {na_remain} null values remaining in the description column.')
# Out:
# There are 0 null values remaining in the description column.

# %%
# Reset the index
meta_df.reset_index(drop = True, inplace = True)

# Check results
meta_df
# Out:
#                                                  category  \
# 0                                   [Movies & TV, Movies]
# 1                                   [Movies & TV, Movies]
# 2                                   [Movies & TV, Movies]
# 3       [Movies & TV, Genre for Featured Categories, E...
# 4                                   [Movies & TV, Movies]
# ...                                                   ...
# 174507  [Movies & TV, Studio Specials, Sony Pictures H...
# 174508                              [Movies & TV, Movies]
# 174509    [Movies & TV, Independently Distributed, Drama]
# 174510  [Movies & TV, Genre for Featured Categories, A...
# 174511                     [Movies & TV, Blu-ray, Movies]
#
#                                                     title  \
# 0                       My Fair Pastry (Good Eats Vol. 9)
# 1       Barefoot Contessa (with Ina Garten), Entertain...
# 2                       Rise and Swine (Good Eats Vol. 7)
# 3                    The Power of the Cross Joseph Prince
# 4                                   Live in Houston [VHS]
# ...                                                   ...
# 174507                                      Verdi: Otello
# 174508               Mr. Miracle - Ihn schickt der Himmel
# 174509                                      The President
# 174510                          She.....Who Would Be Pope
# 174511  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []        Alton Brown
# 1       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 2                                [B000P1CKES, B000NR4CRM]        Alton Brown
# 3                                                      []      Joseph Prince
# 4                                                      []     Douglas Miller
# ...                                                   ...                ...
# 174507  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 174508                                                 []
# 174509  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 174510                                       [B004L690XW]        Liv Ullmann
# 174511  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#                               rank  \
# 0         370,026 in Movies & TV (
# 1         342,914 in Movies & TV (
# 2         351,684 in Movies & TV (
# 3         444,474 in Movies & TV (
# 4       1,005,955 in Movies & TV (
# ...                            ...
# 174507     68,026 in Movies & TV (
# 174508    344,483 in Movies & TV (
# 174509    199,854 in Movies & TV (
# 174510    246,494 in Movies & TV (
# 174511    239,915 in Movies & TV (
#
#                                                 also_view        asin  \
# 0                                                      []  0000143529
# 1       [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  0000143588
# 2                                            [B0015SVNXY]  0000143502
# 3                                                      []  000073991X
# 4                                                      []  000107461X
# ...                                                   ...         ...
# 174507  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...  B01HJ1INB0
# 174508                                                 []  B01HJ3E0PQ
# 174509                           [B01GWCHP2U, B0009PW3RE]  B01HJ6R77G
# 174510                                       [B0000C23HX]  B01HJCCLOY
# 174511  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...  B01HJF79XO
#
#                                                   details  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 174507  {'Language:': 'English', 'Subtitles:': 'Italia...
# 174508  {'Language:': 'German (Dolby Digital 5.1), Eng...
# 174509  {'Language:': 'Georgian', 'Subtitles:': 'Engli...
# 174510   {'Language:': 'English', 'ASIN: ': 'B01HJCCLOY'}
# 174511                           {'ASIN: ': 'B01HJF79XO'}
#
#                                             description_0
# 0       Disc 1: Flour Power (Scones; Shortcakes; South...
# 1       Barefoot Contessa Volume 2: On these three dis...
# 2       Rise and Swine (Good Eats Vol. 7) includes bon...
# 3       Have failures in your life caused you to feel ...
# 4       Track Listings 1. Come On Everybody 2. My Stre...
# ...                                                   ...
# 174507  Tony Award-winning director Bartlett Sher prob...
# 174508  Mr. Miracle DVD Region 2 need an all region DV...
# 174509  The President and his family rule the land wit...
# 174510  Filmed in 1972 as Pope Joan, Michael Andersons...
# 174511                                Japanese Rare Items
#
# [174512 rows x 9 columns]

# %%
meta_df['description_0'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Process `category` column

# %%
meta_df['category'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Movies & TV, Movies]                                                                                                                                                                                                                                                                                                                19249
# [Movies & TV, Genre for Featured Categories, Action & Adventure]                                                                                                                                                                                                                                                                      9442
# [Movies & TV, Genre for Featured Categories, Drama]                                                                                                                                                                                                                                                                                   8271
# [Movies & TV, Genre for Featured Categories, Documentary]                                                                                                                                                                                                                                                                             7969
# [Movies & TV, Genre for Featured Categories, Special Interests]                                                                                                                                                                                                                                                                       7452
#                                                                                                                                                                                                                                                                                                                                      ...
# [Movies & TV, Spanish Language, Televison y documentales]                                                                                                                                                                                                                                                                                1
# [Movies & TV, Studio Specials, Warner Home Video, Warner Video Bargains, Military & War]                                                                                                                                                                                                                                                 1
# [Movies & TV, Genre for Featured Categories, Special Interests, In this video you will see demonstrations from a group of Hollywood's finest artists as they create a prosthetic makeup including false teeth and hair Also includes an interview and career profile of makeup legend Tom Burman., While Supplies Last As always]        1
# [Movies & TV, NCAA on Demand]                                                                                                                                                                                                                                                                                                            1
# [Movies & TV, Charlie Rose Store, Other Topics, In Memoriam]                                                                                                                                                                                                                                                                             1
# Name: category, Length: 688, dtype: int64

# %%
cate_split_df = pd.DataFrame(meta_df['category'].tolist()).add_prefix('category_')

# Check results
cate_split_df
# Out:
#          category_0                     category_1  \
# 0       Movies & TV                         Movies
# 1       Movies & TV                         Movies
# 2       Movies & TV                         Movies
# 3       Movies & TV  Genre for Featured Categories
# 4       Movies & TV                         Movies
# ...             ...                            ...
# 174507  Movies & TV                Studio Specials
# 174508  Movies & TV                         Movies
# 174509  Movies & TV      Independently Distributed
# 174510  Movies & TV  Genre for Featured Categories
# 174511  Movies & TV                        Blu-ray
#
#                               category_2                category_3 category_4  \
# 0                                   None                      None       None
# 1                                   None                      None       None
# 2                                   None                      None       None
# 3                     Exercise & Fitness                      None       None
# 4                                   None                      None       None
# ...                                  ...                       ...        ...
# 174507  Sony Pictures Home Entertainment  All Sony Pictures Titles       None
# 174508                              None                      None       None
# 174509                             Drama                      None       None
# 174510                Action & Adventure                      None       None
# 174511                            Movies                      None       None
#
#        category_5 category_6
# 0            None       None
# 1            None       None
# 2            None       None
# 3            None       None
# 4            None       None
# ...           ...        ...
# 174507       None       None
# 174508       None       None
# 174509       None       None
# 174510       None       None
# 174511       None       None
#
# [174512 rows x 7 columns]

# %%
cate_split_df['category_0'].value_counts()
# Out:
# Movies & TV    174340
# Name: category_0, dtype: int64

# %% [markdown]
# The first column does not contain any useful information other than saying everything is Movies & TV, thus remove the first column

# %%
cate_split_df.drop(columns= 'category_0', inplace = True)

# Check results
cate_split_df
# Out:
#                            category_1                        category_2  \
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 174507                Studio Specials  Sony Pictures Home Entertainment
# 174508                         Movies                              None
# 174509      Independently Distributed                             Drama
# 174510  Genre for Featured Categories                Action & Adventure
# 174511                        Blu-ray                            Movies
#
#                       category_3 category_4 category_5 category_6
# 0                           None       None       None       None
# 1                           None       None       None       None
# 2                           None       None       None       None
# 3                           None       None       None       None
# 4                           None       None       None       None
# ...                          ...        ...        ...        ...
# 174507  All Sony Pictures Titles       None       None       None
# 174508                      None       None       None       None
# 174509                      None       None       None       None
# 174510                      None       None       None       None
# 174511                      None       None       None       None
#
# [174512 rows x 6 columns]

# %% [markdown]
# Check the number of Null values for each column.

# %%
cate_split_df.isna().sum()/cate_split_df.shape[0]
# Out:
# category_1    0.000986
# category_2    0.151651
# category_3    0.842183
# category_4    0.983720
# category_5    0.999983
# category_6    0.999994
# dtype: float64

# %% [markdown]
# Drop catetgories 3-6 because majority of the data are null values.

# %%
cate_split_df = cate_split_df[['category_1','category_2']]

# Check results
cate_split_df
# Out:
#                            category_1                        category_2
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 174507                Studio Specials  Sony Pictures Home Entertainment
# 174508                         Movies                              None
# 174509      Independently Distributed                             Drama
# 174510  Genre for Featured Categories                Action & Adventure
# 174511                        Blu-ray                            Movies
#
# [174512 rows x 2 columns]

# %% [markdown]
# Combine the above category dataframe with the meta_df and drop the category column from the meta_df

# %%
meta_df = pd.concat([meta_df.drop(columns = 'category'), cate_split_df], axis = 1)

# Check results
meta_df
# Out:
#                                                     title  \
# 0                       My Fair Pastry (Good Eats Vol. 9)
# 1       Barefoot Contessa (with Ina Garten), Entertain...
# 2                       Rise and Swine (Good Eats Vol. 7)
# 3                    The Power of the Cross Joseph Prince
# 4                                   Live in Houston [VHS]
# ...                                                   ...
# 174507                                      Verdi: Otello
# 174508               Mr. Miracle - Ihn schickt der Himmel
# 174509                                      The President
# 174510                          She.....Who Would Be Pope
# 174511  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []        Alton Brown
# 1       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 2                                [B000P1CKES, B000NR4CRM]        Alton Brown
# 3                                                      []      Joseph Prince
# 4                                                      []     Douglas Miller
# ...                                                   ...                ...
# 174507  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 174508                                                 []
# 174509  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 174510                                       [B004L690XW]        Liv Ullmann
# 174511  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#                               rank  \
# 0         370,026 in Movies & TV (
# 1         342,914 in Movies & TV (
# 2         351,684 in Movies & TV (
# 3         444,474 in Movies & TV (
# 4       1,005,955 in Movies & TV (
# ...                            ...
# 174507     68,026 in Movies & TV (
# 174508    344,483 in Movies & TV (
# 174509    199,854 in Movies & TV (
# 174510    246,494 in Movies & TV (
# 174511    239,915 in Movies & TV (
#
#                                                 also_view        asin  \
# 0                                                      []  0000143529
# 1       [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...  0000143588
# 2                                            [B0015SVNXY]  0000143502
# 3                                                      []  000073991X
# 4                                                      []  000107461X
# ...                                                   ...         ...
# 174507  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...  B01HJ1INB0
# 174508                                                 []  B01HJ3E0PQ
# 174509                           [B01GWCHP2U, B0009PW3RE]  B01HJ6R77G
# 174510                                       [B0000C23HX]  B01HJCCLOY
# 174511  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...  B01HJF79XO
#
#                                                   details  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 174507  {'Language:': 'English', 'Subtitles:': 'Italia...
# 174508  {'Language:': 'German (Dolby Digital 5.1), Eng...
# 174509  {'Language:': 'Georgian', 'Subtitles:': 'Engli...
# 174510   {'Language:': 'English', 'ASIN: ': 'B01HJCCLOY'}
# 174511                           {'ASIN: ': 'B01HJF79XO'}
#
#                                             description_0  \
# 0       Disc 1: Flour Power (Scones; Shortcakes; South...
# 1       Barefoot Contessa Volume 2: On these three dis...
# 2       Rise and Swine (Good Eats Vol. 7) includes bon...
# 3       Have failures in your life caused you to feel ...
# 4       Track Listings 1. Come On Everybody 2. My Stre...
# ...                                                   ...
# 174507  Tony Award-winning director Bartlett Sher prob...
# 174508  Mr. Miracle DVD Region 2 need an all region DV...
# 174509  The President and his family rule the land wit...
# 174510  Filmed in 1972 as Pope Joan, Michael Andersons...
# 174511                                Japanese Rare Items
#
#                            category_1                        category_2
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 174507                Studio Specials  Sony Pictures Home Entertainment
# 174508                         Movies                              None
# 174509      Independently Distributed                             Drama
# 174510  Genre for Featured Categories                Action & Adventure
# 174511                        Blu-ray                            Movies
#
# [174512 rows x 10 columns]

# %% [markdown]
# ## Process `rank` column

# %% [markdown]
# The different values in the rank column will be analyzed.

# %%
meta_df['rank'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                                                           836
# 350,519 in Movies & TV (                                       7
# 490,118 in Movies & TV (                                       6
# 183,035 in Movies & TV (                                       6
# 141,169 in Movies & TV (                                       6
#                                                             ...
# 295,841 in Movies & TV (                                       1
# 58,329 in Movies & TV (                                        1
# 399,472 in Movies & TV (                                       1
# 589,764 in Movies & TV (                                       1
# [>#1,054,280 in Movies & TV (See Top 100 in Movies & TV)]      1
# Name: rank, Length: 138979, dtype: int64

# %% [markdown]
# The words in the rank column are unnecessary so they will be removed so that it only shows the number.

# %%
# Replace the words and the bracket with an empty string
meta_df['rank'] = meta_df['rank'].str.replace(r" in Movies & TV \(","",regex = True)

# Check results
meta_df
# Out:
#                                                     title  \
# 0                       My Fair Pastry (Good Eats Vol. 9)
# 1       Barefoot Contessa (with Ina Garten), Entertain...
# 2                       Rise and Swine (Good Eats Vol. 7)
# 3                    The Power of the Cross Joseph Prince
# 4                                   Live in Houston [VHS]
# ...                                                   ...
# 174507                                      Verdi: Otello
# 174508               Mr. Miracle - Ihn schickt der Himmel
# 174509                                      The President
# 174510                          She.....Who Would Be Pope
# 174511  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []        Alton Brown
# 1       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 2                                [B000P1CKES, B000NR4CRM]        Alton Brown
# 3                                                      []      Joseph Prince
# 4                                                      []     Douglas Miller
# ...                                                   ...                ...
# 174507  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 174508                                                 []
# 174509  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 174510                                       [B004L690XW]        Liv Ullmann
# 174511  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#              rank                                          also_view  \
# 0         370,026                                                 []
# 1         342,914  [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...
# 2         351,684                                       [B0015SVNXY]
# 3         444,474                                                 []
# 4       1,005,955                                                 []
# ...           ...                                                ...
# 174507     68,026  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...
# 174508    344,483                                                 []
# 174509    199,854                           [B01GWCHP2U, B0009PW3RE]
# 174510    246,494                                       [B0000C23HX]
# 174511    239,915  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...
#
#               asin                                            details  \
# 0       0000143529                                                NaN
# 1       0000143588                                                NaN
# 2       0000143502                                                NaN
# 3       000073991X                                                NaN
# 4       000107461X                                                NaN
# ...            ...                                                ...
# 174507  B01HJ1INB0  {'Language:': 'English', 'Subtitles:': 'Italia...
# 174508  B01HJ3E0PQ  {'Language:': 'German (Dolby Digital 5.1), Eng...
# 174509  B01HJ6R77G  {'Language:': 'Georgian', 'Subtitles:': 'Engli...
# 174510  B01HJCCLOY   {'Language:': 'English', 'ASIN: ': 'B01HJCCLOY'}
# 174511  B01HJF79XO                           {'ASIN: ': 'B01HJF79XO'}
#
#                                             description_0  \
# 0       Disc 1: Flour Power (Scones; Shortcakes; South...
# 1       Barefoot Contessa Volume 2: On these three dis...
# 2       Rise and Swine (Good Eats Vol. 7) includes bon...
# 3       Have failures in your life caused you to feel ...
# 4       Track Listings 1. Come On Everybody 2. My Stre...
# ...                                                   ...
# 174507  Tony Award-winning director Bartlett Sher prob...
# 174508  Mr. Miracle DVD Region 2 need an all region DV...
# 174509  The President and his family rule the land wit...
# 174510  Filmed in 1972 as Pope Joan, Michael Andersons...
# 174511                                Japanese Rare Items
#
#                            category_1                        category_2
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 174507                Studio Specials  Sony Pictures Home Entertainment
# 174508                         Movies                              None
# 174509      Independently Distributed                             Drama
# 174510  Genre for Featured Categories                Action & Adventure
# 174511                        Blu-ray                            Movies
#
# [174512 rows x 10 columns]

# %% [markdown]
# ## Process `details` column

# %%
#meta_df['details'].value_counts()

# %% [markdown]
# The details seems to contain the same info as other columns in the dataframe. A check will be performed to see if they contain the same information.

# %%
# Randomly sample from the meta_df details column to see what kind of data is stored in this column
for i in random.sample(range(0, meta_df.shape[0]), 25):
    print(meta_df['details'][i])
# Out:
# {'ASIN: ': 'B0007YR55C'}
# {'ASIN: ': 'B003DSKR3Q'}
# {'ASIN: ': 'B00GF9IC28'}
# {'Language:': 'English, French', 'Subtitles:': 'Spanish', 'ASIN: ': 'B00007L4LV'}
# {'Language:': 'Russian', 'Subtitles:': 'English, French, Russian', 'ASIN: ': 'B00005KH3M'}
# {'ASIN: ': 'B0009AK6F0'}
# {'Language:': 'Japanese, English', 'Subtitles:': 'English', 'ASIN: ': 'B014VB0A4E'}
# {'Language:': 'English', 'ASIN: ': 'B000CQCTKG'}
# {'ASIN: ': 'B00VKPKDWE'}
# {'Language:': 'English', 'Subtitles:': 'English', 'ASIN: ': 'B001QEIHOU'}
# {'Language:': 'English', 'ASIN: ': 'B000ENUJHW'}
# {'Language:': 'English (Dolby Digital 2.0 Stereo)', 'ASIN: ': 'B00008ZZ6T'}
# {'ASIN: ': 'B0001B50JY'}
# {'Language:': 'English', 'ASIN: ': 'B00SWFMBNE'}
# {'Language:': 'English', 'ASIN: ': 'B00005NQGS'}
# {'Language:': 'English', 'ASIN: ': 'B00E4Q6UQ4'}
# {'Language:': 'English (Dolby Digital 5.1)', 'Subtitles:': 'Spanish', 'ASIN: ': 'B00005JLOB'}
# {'ASIN: ': 'B0013W3CFO'}
# {'Language:': 'English', 'ASIN: ': 'B00008G8VF'}
# {'Language:': 'English', 'ASIN: ': 'B000BB1NGS'}
# {'ASIN: ': '6304563752'}
# {'ASIN: ': 'B001BF1HCS'}
# {'Language:': 'English', 'ASIN: ': 'B0002XZVEK'}
# nan
# {'Language:': 'English (DTS 5.1), French (Dolby Digital 5.1), Spanish (Dolby Digital 5.1)', 'Subtitles:': 'Spanish, English, French', 'ASIN: ': 'B005LAIGNC'}

# %% [markdown]
# The majority of the data in this column stores language related information and this is not needed for the NLP reviews recommendation system. Thus this column can be dropped.

# %%
# The details column will be dropped.
meta_df.drop(columns = 'details',inplace = True)

# %%
meta_df
# Out:
#                                                     title  \
# 0                       My Fair Pastry (Good Eats Vol. 9)
# 1       Barefoot Contessa (with Ina Garten), Entertain...
# 2                       Rise and Swine (Good Eats Vol. 7)
# 3                    The Power of the Cross Joseph Prince
# 4                                   Live in Houston [VHS]
# ...                                                   ...
# 174507                                      Verdi: Otello
# 174508               Mr. Miracle - Ihn schickt der Himmel
# 174509                                      The President
# 174510                          She.....Who Would Be Pope
# 174511  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []        Alton Brown
# 1       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 2                                [B000P1CKES, B000NR4CRM]        Alton Brown
# 3                                                      []      Joseph Prince
# 4                                                      []     Douglas Miller
# ...                                                   ...                ...
# 174507  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 174508                                                 []
# 174509  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 174510                                       [B004L690XW]        Liv Ullmann
# 174511  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#              rank                                          also_view  \
# 0         370,026                                                 []
# 1         342,914  [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...
# 2         351,684                                       [B0015SVNXY]
# 3         444,474                                                 []
# 4       1,005,955                                                 []
# ...           ...                                                ...
# 174507     68,026  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...
# 174508    344,483                                                 []
# 174509    199,854                           [B01GWCHP2U, B0009PW3RE]
# 174510    246,494                                       [B0000C23HX]
# 174511    239,915  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...
#
#               asin                                      description_0  \
# 0       0000143529  Disc 1: Flour Power (Scones; Shortcakes; South...
# 1       0000143588  Barefoot Contessa Volume 2: On these three dis...
# 2       0000143502  Rise and Swine (Good Eats Vol. 7) includes bon...
# 3       000073991X  Have failures in your life caused you to feel ...
# 4       000107461X  Track Listings 1. Come On Everybody 2. My Stre...
# ...            ...                                                ...
# 174507  B01HJ1INB0  Tony Award-winning director Bartlett Sher prob...
# 174508  B01HJ3E0PQ  Mr. Miracle DVD Region 2 need an all region DV...
# 174509  B01HJ6R77G  The President and his family rule the land wit...
# 174510  B01HJCCLOY  Filmed in 1972 as Pope Joan, Michael Andersons...
# 174511  B01HJF79XO                                Japanese Rare Items
#
#                            category_1                        category_2
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 174507                Studio Specials  Sony Pictures Home Entertainment
# 174508                         Movies                              None
# 174509      Independently Distributed                             Drama
# 174510  Genre for Featured Categories                Action & Adventure
# 174511                        Blu-ray                            Movies
#
# [174512 rows x 9 columns]

# %% [markdown]
# # Process `asin` column

# %%
meta_df.rename(columns = {'asin':'product_id'}, inplace = True)

# Check results
meta_df
# Out:
#                                                     title  \
# 0                       My Fair Pastry (Good Eats Vol. 9)
# 1       Barefoot Contessa (with Ina Garten), Entertain...
# 2                       Rise and Swine (Good Eats Vol. 7)
# 3                    The Power of the Cross Joseph Prince
# 4                                   Live in Houston [VHS]
# ...                                                   ...
# 174507                                      Verdi: Otello
# 174508               Mr. Miracle - Ihn schickt der Himmel
# 174509                                      The President
# 174510                          She.....Who Would Be Pope
# 174511  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#                                                  also_buy              brand  \
# 0                                                      []        Alton Brown
# 1       [B002I5GNW4, B005WXPVMM, B009UY3W8O, B00N27ID1...         Ina Garten
# 2                                [B000P1CKES, B000NR4CRM]        Alton Brown
# 3                                                      []      Joseph Prince
# 4                                                      []     Douglas Miller
# ...                                                   ...                ...
# 174507  [B01MXE4EVV, B014HFML6E, B07HGR7P4Z, B000F3T3C...     Sonya Yoncheva
# 174508                                                 []
# 174509  [B01M6DA5RJ, B0002F6BFG, B06XRGPHM3, B06XG2N43...  Misha Gomiashvili
# 174510                                       [B004L690XW]        Liv Ullmann
# 174511  [B073XHMCB4, B0714J1MPR, B072MZN33K, B01MYFLZR...
#
#              rank                                          also_view  \
# 0         370,026                                                 []
# 1         342,914  [B002I5GNW4, 0804187045, B009UY3W8O, 060960219...
# 2         351,684                                       [B0015SVNXY]
# 3         444,474                                                 []
# 4       1,005,955                                                 []
# ...           ...                                                ...
# 174507     68,026  [B07BF2PQHM, B00012AST0, B0094AH3Q6, B0007P0LP...
# 174508    344,483                                                 []
# 174509    199,854                           [B01GWCHP2U, B0009PW3RE]
# 174510    246,494                                       [B0000C23HX]
# 174511    239,915  [B071KW44QB, B073XHMCB4, B07KZ4HB41, B01EHI4MO...
#
#         product_id                                      description_0  \
# 0       0000143529  Disc 1: Flour Power (Scones; Shortcakes; South...
# 1       0000143588  Barefoot Contessa Volume 2: On these three dis...
# 2       0000143502  Rise and Swine (Good Eats Vol. 7) includes bon...
# 3       000073991X  Have failures in your life caused you to feel ...
# 4       000107461X  Track Listings 1. Come On Everybody 2. My Stre...
# ...            ...                                                ...
# 174507  B01HJ1INB0  Tony Award-winning director Bartlett Sher prob...
# 174508  B01HJ3E0PQ  Mr. Miracle DVD Region 2 need an all region DV...
# 174509  B01HJ6R77G  The President and his family rule the land wit...
# 174510  B01HJCCLOY  Filmed in 1972 as Pope Joan, Michael Andersons...
# 174511  B01HJF79XO                                Japanese Rare Items
#
#                            category_1                        category_2
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 174507                Studio Specials  Sony Pictures Home Entertainment
# 174508                         Movies                              None
# 174509      Independently Distributed                             Drama
# 174510  Genre for Featured Categories                Action & Adventure
# 174511                        Blu-ray                            Movies
#
# [174512 rows x 9 columns]

# %% [markdown]
# ## Remove the Also_Buy and Also_view columns

# %%
new_df = meta_df.drop(columns = ['also_buy','also_view'])

# Check results
new_df
# Out:
#                                                     title              brand  \
# 0                       My Fair Pastry (Good Eats Vol. 9)        Alton Brown
# 1       Barefoot Contessa (with Ina Garten), Entertain...         Ina Garten
# 2                       Rise and Swine (Good Eats Vol. 7)        Alton Brown
# 3                    The Power of the Cross Joseph Prince      Joseph Prince
# 4                                   Live in Houston [VHS]     Douglas Miller
# ...                                                   ...                ...
# 174507                                      Verdi: Otello     Sonya Yoncheva
# 174508               Mr. Miracle - Ihn schickt der Himmel
# 174509                                      The President  Misha Gomiashvili
# 174510                          She.....Who Would Be Pope        Liv Ullmann
# 174511  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#              rank  product_id  \
# 0         370,026  0000143529
# 1         342,914  0000143588
# 2         351,684  0000143502
# 3         444,474  000073991X
# 4       1,005,955  000107461X
# ...           ...         ...
# 174507     68,026  B01HJ1INB0
# 174508    344,483  B01HJ3E0PQ
# 174509    199,854  B01HJ6R77G
# 174510    246,494  B01HJCCLOY
# 174511    239,915  B01HJF79XO
#
#                                             description_0  \
# 0       Disc 1: Flour Power (Scones; Shortcakes; South...
# 1       Barefoot Contessa Volume 2: On these three dis...
# 2       Rise and Swine (Good Eats Vol. 7) includes bon...
# 3       Have failures in your life caused you to feel ...
# 4       Track Listings 1. Come On Everybody 2. My Stre...
# ...                                                   ...
# 174507  Tony Award-winning director Bartlett Sher prob...
# 174508  Mr. Miracle DVD Region 2 need an all region DV...
# 174509  The President and his family rule the land wit...
# 174510  Filmed in 1972 as Pope Joan, Michael Andersons...
# 174511                                Japanese Rare Items
#
#                            category_1                        category_2
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 174507                Studio Specials  Sony Pictures Home Entertainment
# 174508                         Movies                              None
# 174509      Independently Distributed                             Drama
# 174510  Genre for Featured Categories                Action & Adventure
# 174511                        Blu-ray                            Movies
#
# [174512 rows x 7 columns]

# %% [markdown]
# ## Drop the duplicated rows

# %%
new_df.drop_duplicates(inplace = True,ignore_index = True)

# Check results
new_df
# Out:
#                                                     title              brand  \
# 0                       My Fair Pastry (Good Eats Vol. 9)        Alton Brown
# 1       Barefoot Contessa (with Ina Garten), Entertain...         Ina Garten
# 2                       Rise and Swine (Good Eats Vol. 7)        Alton Brown
# 3                    The Power of the Cross Joseph Prince      Joseph Prince
# 4                                   Live in Houston [VHS]     Douglas Miller
# ...                                                   ...                ...
# 156476                                      Verdi: Otello     Sonya Yoncheva
# 156477               Mr. Miracle - Ihn schickt der Himmel
# 156478                                      The President  Misha Gomiashvili
# 156479                          She.....Who Would Be Pope        Liv Ullmann
# 156480  Mobile Suit Gundam Thunderbolt Limited Edition...
#
#              rank  product_id  \
# 0         370,026  0000143529
# 1         342,914  0000143588
# 2         351,684  0000143502
# 3         444,474  000073991X
# 4       1,005,955  000107461X
# ...           ...         ...
# 156476     68,026  B01HJ1INB0
# 156477    344,483  B01HJ3E0PQ
# 156478    199,854  B01HJ6R77G
# 156479    246,494  B01HJCCLOY
# 156480    239,915  B01HJF79XO
#
#                                             description_0  \
# 0       Disc 1: Flour Power (Scones; Shortcakes; South...
# 1       Barefoot Contessa Volume 2: On these three dis...
# 2       Rise and Swine (Good Eats Vol. 7) includes bon...
# 3       Have failures in your life caused you to feel ...
# 4       Track Listings 1. Come On Everybody 2. My Stre...
# ...                                                   ...
# 156476  Tony Award-winning director Bartlett Sher prob...
# 156477  Mr. Miracle DVD Region 2 need an all region DV...
# 156478  The President and his family rule the land wit...
# 156479  Filmed in 1972 as Pope Joan, Michael Andersons...
# 156480                                Japanese Rare Items
#
#                            category_1                        category_2
# 0                              Movies                              None
# 1                              Movies                              None
# 2                              Movies                              None
# 3       Genre for Featured Categories                Exercise & Fitness
# 4                              Movies                              None
# ...                               ...                               ...
# 156476                Studio Specials  Sony Pictures Home Entertainment
# 156477                         Movies                              None
# 156478      Independently Distributed                             Drama
# 156479  Genre for Featured Categories                Action & Adventure
# 156480                        Blu-ray                            Movies
#
# [156481 rows x 7 columns]

# %% [markdown]
# Check the product_id of items to determine if any are still duplicated

# %%
new_df['product_id'].value_counts()
# Out:
# B001LMAK60    1
# B00005A0PY    1
# B001AYWY7C    1
# B0009K8LCA    1
# B000AV2GJM    1
#              ..
# 6304160240    1
# B000YDBP2A    1
# B00465I1BA    1
# B0130MKDRO    1
# 630447525X    1
# Name: product_id, Length: 156481, dtype: int64

# %% [markdown]
# All product_ids are unqiue, therefore, every row is unique and the duplicated rows are gone.

# %% [markdown]
# # 3. Export preprocessed meta data

# %% [markdown]
# The preprocessed meta data will be exported into a csv file to be used in the recommendation system

# %%
new_df.to_csv('clean_meta.csv',index = False)

# %% [markdown]
# # 4. Conclusion and Future Work
#
# 1) Web scrape amazon.ca for the products with missing descriptions and prices
# 2) Incorporate the `also buy` and `also viewed` columns into the recommendation system.
